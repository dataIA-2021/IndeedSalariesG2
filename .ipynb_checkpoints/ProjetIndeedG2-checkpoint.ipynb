# %%
import csv
from datetime import datetime
import requests
from bs4 import BeautifulSoup
import pandas as pd
import math
import re
import numpy as np

# %% [markdown]
# ## Test de récupération des intitulés des offres

# %%
#Fonction de récupération de l'URl de la recherche à partir du motif et de la localisation de la recherche
def get_url(job, location):
    """Generate an URL from Job and Location"""
    template = 'https://fr.indeed.com/jobs?q={}&l={}&sort=date'
    url = template.format(job, location)
    return(url)

# %%
#test de la fonction get_url()
url = get_url('Data', 'Bretagne')
url
# Out:
# 'https://fr.indeed.com/jobs?q=Data&l=Bretagne&sort=date&filter=0'

# %% [markdown]
# # Liens

# %%
#Fonction générant la liste des liens des offres à partir d'un mot-clé et d'une localisation
def generate_page_url(Query, Location, Pages):
    '''
    Parameters
    ----------
    Query : Str
        Motif de la recherche
    Location : Str
        Localisation de la recherche

    Returns
    -------
    Liste d'url contenant la liste des pages issues de la recherche'

    '''
    home_url = []
    base_url = get_url(Query, Location)
    
    #soup = BeautifulSoup((requests.get(base_url)).text, 'html.parser')
    #Pages = round(int(soup.find(id="searchCountPages").get_text().split()[3])/10)
    
    for k in range(0, Pages):
        home_url.append(base_url + '&start=' + str(k*10))
    
    return(home_url)

# %%
#test de la fonction generate_page_url()
liste_url = generate_page_url('Data', 'Centre-Val+de+Loire', 15)
liste_url
# Out:
# ['https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=0',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=10',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=20',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=30',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=40',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=50',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=60',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=70',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=80',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=90',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=100',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=110',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=120',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=130',
#  'https://fr.indeed.com/jobs?q=Data&l=Centre-Val+de+Loire&sort=date&filter=0&start=140']

# %%
#Test de la récupération des IDs sur la "home page"
response = requests.get(liste_url[0])
soup = BeautifulSoup(response.text, 'html.parser')
card = soup.find_all('a')
id = []
for k in card:
    if 'data-jk' in k.attrs:
        id.append(k.attrs['data-jk'])
len(id), id
# Out:
# (15,
#  ['dcee9ca24d0ea05e',
#   'dc481509bbff9dd1',
#   'a30e3e863f9b3a13',
#   '34f5f637a1c4f830',
#   '87e0a564d9190aa2',
#   'de14d959d9b11394',
#   'a25ddcc7a0af8396',
#   '5897aa5ebf49f79e',
#   '6395906f259aa1ee',
#   '8c8000b23d3db1fa',
#   '98f347d4fe23991d',
#   '3bd3eff7dc148e9c',
#   '076f202622c9a55a',
#   '4086d6889d9f474e',
#   '5b2e4528626a2c37'])

# %%
#Fonction de récupération des URLs individuelles à partir des URLs de la "home page"
def recup_urls(home_url):
    '''
    Parameters
    ----------
    home_url : List
        Liste contenant les URLs issues de la recherche dont l'on souhaite obtenir les URLs 
        individuelles des offres'
    Returns
    -------
    Liste contenant les URLs individuelles des offres à scraper.
    '''
    LINKS = []
    
    for URL in home_url:
        response = requests.get(URL)    
        card = BeautifulSoup(response.text, 'html.parser').find_all('a')
        for k in card:
            if 'data-jk' in k.attrs:
                link = 'https://fr.indeed.com/viewjob?jk=' + (k.attrs['data-jk']) 
                if link not in LINKS:
                    LINKS.append(link)
    return(LINKS)

# %%
liste_url = generate_page_url('Data', 'Provence-Alpes-Côte%20d%27Azur', 20)
job_url = recup_urls(liste_url)
job_url, len(job_url)

# %%
#Récupération empirique des liens pour compenser les problèmes de liens manquants (A ne pas apeller)
def recup_emp():
    links = []
    nlinks = []

    for k in range(25):
        links += recup_urls()
        links = list(dict.fromkeys(links))
        nlinks.append(len(links))
    print(len(links), links, nlinks)

# %%
#Fonction récupérant les données Titre, Type de Contrat, Entreprise, Localisation, Region, Salaire et Description
def scrap_job(link_list, region):
    """
    Parameters
    ----------
    link_list : list
        Liste de str contenant la liste des liens individuels des différentes offres du site

    Returns
    -------
    df : Pandas.Dataframe
        Dataframe composé des champs Lien, Titre, Entreprise, Type de contrat, Localisation,
        Region, Salaire et Description.
    """
    titre = []
    typecontrat = []
    entreprise = []
    localisation = []
    lregion = []
    salaire = []
    description = []
    
    
    
    for k, link in enumerate(link_list):
        print('Lien ', k+1,'sur ', len(link_list))
        
        response = requests.get(link)    
        soup = BeautifulSoup(response.text, 'html.parser')
        
        try:titre.append(soup.find('h1').get_text())
        except:titre.append('NA')    
        
        try: typecontrat.append(soup.find('span', 'jobsearch-JobMetadataHeader-item icl-u-xs-mt--xs').get_text())
        except : typecontrat.append('NA')

        try:entreprise.append(soup.find_all("div", "icl-u-lg-mr--sm icl-u-xs-mr--xs")[1].get_text())
        except:entreprise.append('NA')
            
        try:localisation.append(soup.find('div','icl-u-xs-mt--xs icl-u-textColor--secondary jobsearch-JobInfoHeader-subtitle jobsearch-DesktopStickyContainer-subtitle').find_all('div')[-2].get_text())
        except:localisation.append('NA')
        
        try : lregion.append(region)
        except : lregion.append('NA')
        
        try: salaire.append(soup.find('span', 'icl-u-xs-mr--xs attribute_snippet').get_text())
        except:salaire.append('NA')
        
        try: description.append(soup.find(id="jobDescriptionText").get_text())
        except:description.append('NA')
     
    Lien = pd.Series(link_list)
    Titre = pd.Series(titre)
    TypeContrat = pd.Series(typecontrat)
    Entreprise = pd.Series(entreprise)
    Localisation = pd.Series(localisation)
    Region = pd.Series(lregion)
    Salaire = pd.Series(salaire)
    Description = pd.Series(description)
    
    
    
    frame = {'Lien': Lien,
             'Poste': Titre,
             'Typedecontrat':TypeContrat,
             'Entreprise': Entreprise,
             'Departement':Localisation,
             'Region' : Region,
             'Salaire':Salaire,
             'Description':Description}
    
    df = pd.DataFrame(frame)
    return(df)

# %%
#Récupération des données de la Bretagne.
df2 = scrap_job(job_url, 'Centre-Val-de-Loire')
df2.head()
# Out:
# Lien  1 sur  83
# Lien  2 sur  83
# Lien  3 sur  83
# Lien  4 sur  83
# Lien  5 sur  83
# Lien  6 sur  83
# Lien  7 sur  83
# Lien  8 sur  83
# Lien  9 sur  83
# Lien  10 sur  83
# Lien  11 sur  83
# Lien  12 sur  83
# Lien  13 sur  83
# Lien  14 sur  83
# Lien  15 sur  83
# Lien  16 sur  83
# Lien  17 sur  83
# Lien  18 sur  83
# Lien  19 sur  83
# Lien  20 sur  83
# Lien  21 sur  83
# Lien  22 sur  83
# Lien  23 sur  83
# Lien  24 sur  83
# Lien  25 sur  83
# Lien  26 sur  83
# Lien  27 sur  83
# Lien  28 sur  83
# Lien  29 sur  83
# Lien  30 sur  83
# Lien  31 sur  83
# Lien  32 sur  83
# Lien  33 sur  83
# Lien  34 sur  83
# Lien  35 sur  83
# Lien  36 sur  83
# Lien  37 sur  83
# Lien  38 sur  83
# Lien  39 sur  83
# Lien  40 sur  83
# Lien  41 sur  83
# Lien  42 sur  83
# Lien  43 sur  83
# Lien  44 sur  83
# Lien  45 sur  83
# Lien  46 sur  83
# Lien  47 sur  83
# Lien  48 sur  83
# Lien  49 sur  83
# Lien  50 sur  83
# Lien  51 sur  83
# Lien  52 sur  83
# Lien  53 sur  83
# Lien  54 sur  83
# Lien  55 sur  83
# Lien  56 sur  83
# Lien  57 sur  83
# Lien  58 sur  83
# Lien  59 sur  83
# Lien  60 sur  83
# Lien  61 sur  83
# Lien  62 sur  83
# Lien  63 sur  83
# Lien  64 sur  83
# Lien  65 sur  83
# Lien  66 sur  83
# Lien  67 sur  83
# Lien  68 sur  83
# Lien  69 sur  83
# Lien  70 sur  83
# Lien  71 sur  83
# Lien  72 sur  83
# Lien  73 sur  83
# Lien  74 sur  83
# Lien  75 sur  83
# Lien  76 sur  83
# Lien  77 sur  83
# Lien  78 sur  83
# Lien  79 sur  83
# Lien  80 sur  83
# Lien  81 sur  83
# Lien  82 sur  83
# Lien  83 sur  83
#                                                 Lien  \
# 0  https://fr.indeed.com/viewjob?jk=5d6e0b14d06f8a04
# 1  https://fr.indeed.com/viewjob?jk=d3255caf45c89495
# 2  https://fr.indeed.com/viewjob?jk=57399fca19dea62c
# 3  https://fr.indeed.com/viewjob?jk=fdf5922e9f57a3f9
# 4  https://fr.indeed.com/viewjob?jk=c384bb76e7cc8271
#
#                                                Poste         Typedecontrat  \
# 0               Ingénieur Data confirmé (h/f), Tours                   CDI
# 1  (F/H) Ingénieur d’études/data analyst/analyse ...                   CDD
# 2  (F/H) Ingénieur d’études/data analyst/édition ...                   CDD
# 3                                      Data Engineer                   CDI
# 4           Gestionnaire Base de données projets H/F   -  Temps plein, CDD
#
#                                         Entreprise                Departement  \
# 0                               SPRINGPROFESSIONAL                 Tours (37)
# 1  Institut National de l'Information Géographique  Nogent-sur-Vernisson (45)
# 2  Institut National de l'Information Géographique  Nogent-sur-Vernisson (45)
# 3                                         NEO SOFT                 Tours (37)
# 4                                 RECKITT CHARTRES             28000 Chartres
#
#                 Region                     Salaire  \
# 0  Centre-Val-de-Loire                          NA
# 1  Centre-Val-de-Loire                          NA
# 2  Centre-Val-de-Loire                          NA
# 3  Centre-Val-de-Loire                          NA
# 4  Centre-Val-de-Loire  34 000 € - 38 000 € par an
#
#                                          Description
# 0  Votre mission\nA la recherche de nouvelles aff...
# 1  L’Institut national de l’information géographi...
# 2  L’Institut national de l’information géographi...
# 3  Votre mission\nAfin d'accompagner l'un de nos ...
# 4  REJOIGNEZ LES EQUIPES RECKITT BENCKISER CHARTR...

# %%
#Export du csv sans index
df2.to_csv('centre_sale.csv', index = False)

# %% [markdown]
# # Nettoyage

# %%
#Fonctions des nettoyage des différentes features
def nettoyage_contrat(df):
    '''
    Parameters
    ----------
    df : Pandas.DataFrame
        Dataframe dont on souhaite nettoyer la colonne 'Typedecontrat'

    Returns
    -------
    df : Pandas.Dataframe
        Dataframe avec la colonne Typedecontrat nettoyée avec uniquement CDI, CDD, Intérim ou Stage
    '''
    df.Typedecontrat = df.Typedecontrat.apply(str)
    TContrat = []
    df['Typedecontrat'].fillna('CDI',inplace=True)
    for k in df.index:
        Type=re.findall(r"CDI|CDD|Intérim|Stage", df['Typedecontrat'][k], re.IGNORECASE)
        try: TContrat.append(Type[0])
        except: TContrat.append('CDI')
    df['Typedecontrat'] = pd.Series(TContrat)
    return(df)

def nettoyage_departement(df):
    '''
    Parameters
    ----------
    df : Pandas.DataFrame
        Dataframe dont on souhaite nettoyer la colonne 'Departement'

    Returns
    -------
    df : Pandas.DataFrame
        Dataframe avec la colonne Departement contenant uniquement le numéro de Département 
        ou 0 si France ou Télétravail
    '''
    df.Departement = df.Departement.apply(str)
    df['Departement'].replace(to_replace=r'\d[e]|\d\d[e]', value='', regex=True,inplace=True)
    Postal = []
    for k in df.index:
        Localisation = re.findall(r"\d\d*", df['Departement'][k], re.IGNORECASE)
        if len(Localisation) != 1:
            Postal.append(0)
        else :
            if int(Localisation[0]) > 100:
                Postal.append(math.floor(int(Localisation[0]) / 1000))
            else: Postal.append(int(Localisation[0]))
    df['Departement'] = pd.Series(Postal)
    return(df)

def salary_stripper(df, column = 'Salaire'):
    df.Salaire = df.Salaire.apply(str)
    df[column] = df[column].replace({'\€':''}, regex = True)
    df[column].replace(regex=True,inplace=True,to_replace=r'\D',value=r' ')
    df[column] = df[column].str.replace(' ',',')
    df = pd.concat([df, (df[column].str.split(',,,', 1, expand=True).rename(columns={0:'Low', 1:'High'}))], axis=1)
    df['Low'] = df['Low'].str.replace(',','')
    df['Low'] = df['Low'].apply(pd.to_numeric)
    df.drop(column, axis=1, inplace=True)
    df['High'] = df['High'].str.replace(',','')
    df['High'] = df['High'].apply(pd.to_numeric)
    df['Salaire'] = df[['Low', 'High']].mean(axis=1)
    df = df.drop(columns=['Low','High'])
    return (df)

def nettoyage_salaire(df):
    '''
    Parameters
    ----------
    df : Pandas.DataFrame
        Dataframe dont on souhaite uniformiser la colonne 'Salaire'

    Returns
    -------
    df : Pandas.DataFrame
        Dataframe dont la colonne 'Salaire' est uniformisée : 
        salaires journa mis à nan, salaires mensuels convertis en annuels
    '''
    salaire = []
    for c, k in enumerate(df.Salaire):
        if df.Salaire.isna()[c] == False:
            if k < 1000: salaire.append(np.nan)
            elif k < 10000: salaire.append(k * 12)
            else: salaire.append(k)
        else : salaire.append(np.nan)
    df.Salaire = pd.Series(salaire)
    return(df)

def nettoyage_poste(df):
    '''
    Parameters
    ----------
    df : Pandas.DataFrame
        Dataframe dont on souhaite uniformiser les intitulés des postes

    Returns
    -------
    df : Pandas.DataFrame
        DataFrame dont les postes ont été regroupés
    '''
    df.Poste = df.Poste.apply(str)
    df['Poste'] = df['Poste'].str.upper()
    PosteDescrip = []
    for k in df.index:
        if re.findall(r"INGENIEUR|ENGINEER", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA INGENIEUR')
        elif re.findall(r"ENGINEER", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA INGENIEUR')
        elif re.findall(r"MANA|MASTER|PROJET", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA MANAGER')
        elif re.findall(r"SCIENTIST", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA SCIENTIST')
        elif re.findall(r"ARCHITECT", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA ARCHITECT')
        elif re.findall(r"DEVELOP", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DEVELOPPEUR')
        elif re.findall(r"BASE", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA MANAGER')
        elif re.findall(r"TECH", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('TECHNICIEN')
        elif re.findall(r"ANALY", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA ANALYSTE')
        elif re.findall(r"CONSUL|BIG", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('CONSULTANT')
        elif re.findall(r"MARK", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('DATA MARKETING')
        elif re.findall(r"DONN", df['Poste'][k], re.IGNORECASE):
            PosteDescrip.append('GESTIONNAIRE DONNEES')
        #else: PosteDescrip.append(df['Poste'][k])
        else : PosteDescrip.append('0')
    df['Poste'] = pd.Series(PosteDescrip)
    return(df)

def nettoyage(df):
    '''
    Parameters
    ----------
    df : Pandas.DataFrame
        Dataframe dont ou souhaite nettoyer les colonnes 'Poste', 'Typedecontrat', 'Departement' et 'Salaire'
        DESCRIPTION.
    Returns
    -------
    df : Pandas.DataFrame
        Dataframe avec les 4 colonnes nettoyées
    '''
    df = salary_stripper(df,'Salaire')
    df = nettoyage_salaire(df)
    df = nettoyage_contrat(df)
    df = nettoyage_departement(df)
    df = nettoyage_poste(df)
    return(df)

# %%
#Nettoyage d'un df + Export
df = pd.read_csv('Provences-Alpes-Cote_d_Azur.csv')
df = nettoyage(df)
#df = df.drop(columns = 'Unnamed: 0')
df.to_csv('paca_propre.csv', index = False)
df
# Out:
#                                                   Lien           Poste  \
# 0    https://fr.indeed.com/viewjob?jk=9b7c1ce937f77a62   DATA ANALYSTE
# 1    https://fr.indeed.com/viewjob?jk=3d7382dce8575ab6  DATA SCIENTIST
# 2    https://fr.indeed.com/viewjob?jk=b510b1c5450d86d7               0
# 3    https://fr.indeed.com/viewjob?jk=1d96c982fe1a3407    DATA MANAGER
# 4    https://fr.indeed.com/viewjob?jk=f061201c62aa79e3               0
# ..                                                 ...             ...
# 172  https://fr.indeed.com/viewjob?jk=9ee3735e6f7a2273      CONSULTANT
# 173  https://fr.indeed.com/viewjob?jk=c666590f8613a421      CONSULTANT
# 174  https://fr.indeed.com/viewjob?jk=ff03f5837fd71b36    DATA MANAGER
# 175  https://fr.indeed.com/viewjob?jk=46bec64886cc7ce0      TECHNICIEN
# 176  https://fr.indeed.com/viewjob?jk=3a9fc51f1880311d    DATA MANAGER
#
#     Typedecontrat                               Entreprise  Departement  \
# 0             CDI                                 GENWAVES           13
# 1             CDD                 Aix Marseille Université           13
# 2             CDI  Mindquest | CF - Cabinet de recrutement           13
# 3             CDI                                  DORIANE            6
# 4             CDI                               OpenSkills           13
# ..            ...                                      ...          ...
# 172           CDI                                   KLANIK           13
# 173           CDI                      Business & Decision           13
# 174           CDI                          Homair Vacances           13
# 175           CDI                        Page Personnel FR           13
# 176           CDI                                 Adsearch           13
#
#                              Region  \
# 0    Provence-Alpes-Côte%20d%27Azur
# 1    Provence-Alpes-Côte%20d%27Azur
# 2    Provence-Alpes-Côte%20d%27Azur
# 3    Provence-Alpes-Côte%20d%27Azur
# 4    Provence-Alpes-Côte%20d%27Azur
# ..                              ...
# 172  Provence-Alpes-Côte%20d%27Azur
# 173  Provence-Alpes-Côte%20d%27Azur
# 174  Provence-Alpes-Côte%20d%27Azur
# 175  Provence-Alpes-Côte%20d%27Azur
# 176  Provence-Alpes-Côte%20d%27Azur
#
#                                            Description  Salaire
# 0    Data Analyst F/H\nRef. Apec : 167810005W / Ref...      NaN
# 1    Data Scientist pour l'imagerie en Neuroscience...      NaN
# 2    Ingénieur Data Sénior - 13 F/H\nRef. Apec : 16...      NaN
# 3    CONSULTANT BASES DE DONNEES SQL F/H\nRef. Apec...      NaN
# 4    Développeur Front-End Java/JS – Data visualisa...      NaN
# ..                                                 ...      ...
# 172  Ingénieur Big Data F/H\nRef. Apec : 167437839W...      NaN
# 173  Description de l'entreprise\nDepuis 30 ans, Bu...      NaN
# 174  Présentation de l'entreprise\nEuropean Camping...  42500.0
# 175  L'Ingénieur Données Technique Groupe Airbus tr...      NaN
# 176  Administrateur Base de données (DBA) H/F\nEn b...      NaN
#
# [177 rows x 8 columns]

# %%
#Assemblage des différents df
df0 = pd.read_csv('France_V9.csv')
df1 = pd.read_csv('normandie_propre.csv')
df = pd.concat([df0, df1])
df.to_csv('France_V10.csv', index = False)

# %%
df = pd.read_csv('France_V10.csv')
df.replace('Aquitaine', 'Nouvelle-Aquitaine', inplace = True)
df.replace('Rhône-Alpes', 'Auvergne-Rhône-Alpes', inplace = True)
df.replace('Saône-et-Loire', 'Bourgogne-Franche-Comté', inplace = True)
df.replace('Ain', 'Auvergne-Rhône-Alpes', inplace = True)
df.replace('Île de France', 'Île-de-France', inplace = True)
df.replace('Provence-Alpes-Côte%20d%27Azur', "Provence-Âlpes-Côte-D'Azur", inplace = True)
df.Region.value_counts().sum()
# Out:
# 2795

# %%
df.drop_duplicates(subset = 'Lien', inplace = True)
df.Poste.replace('0', 'AUTRES', inplace = True)
df.Poste.value_counts()
# Out:
# DATA MANAGER            485
# AUTRES                  344
# DATA ANALYSTE           324
# DATA INGENIEUR          296
# DATA SCIENTIST          185
# GESTIONNAIRE DONNEES    158
# CONSULTANT              133
# DATA ARCHITECT           89
# TECHNICIEN               87
# DEVELOPPEUR              13
# DATA MARKETING           11
# Name: Poste, dtype: int64

# %%
#df.to_csv('France_V11.csv', index = False)

# %%
#Nettoyage du premier df
#NE PAS APELLER
def nett_df1():
    df = pd.read_csv('Indeed_Salaries.csv')
    df.drop(columns=['Département','Type de contrat',"Nombre d'avis", 'Note Moyenne', 'Diplôme', "Années d'expérience", 'Temps de travail', 'Technologies','Langues', 'Industrie'], inplace = True)
    df = df.rename(columns={"Type de Contrat": "Typedecontrat", "Localisation":"Departement"})
    region = []
    for k in df.index :
        region.append("Centre-Val-de-Loire")
    df['Region'] = pd.Series(region)
    df = df[["Lien", "Poste", "Typedecontrat", "Entreprise", "Departement", "Region", "Salaire", "Description"]]
    df = nettoyage(df)
    df.to_csv('centrevaldeloire_propre.csv', index = False)
    df.head(20)
# Out:
#                                                  Lien                 Poste  \
# 0   https://fr.indeed.com/viewjob?jk=5b2e4528626a2c37  GESTIONNAIRE DONNEES
# 1   https://fr.indeed.com/viewjob?jk=a25ddcc7a0af8396  GESTIONNAIRE DONNEES
# 2   https://fr.indeed.com/viewjob?jk=ba5c2f88b0176120            TECHNICIEN
# 3   https://fr.indeed.com/viewjob?jk=d1fa73c363aa27d0          DATA MANAGER
# 4   https://fr.indeed.com/viewjob?jk=6f7788bc07e79181          DATA MANAGER
# 5   https://fr.indeed.com/viewjob?jk=fbbdd347848cec7e          DATA MANAGER
# 6   https://fr.indeed.com/viewjob?jk=866fcdb3235fef6e        DATA SCIENTIST
# 7   https://fr.indeed.com/viewjob?jk=b94d544f79c5e584        DATA INGENIEUR
# 8   https://fr.indeed.com/viewjob?jk=50aca5cbf81cc201          DATA MANAGER
# 9   https://fr.indeed.com/viewjob?jk=4d41a1a3de8973d1  GESTIONNAIRE DONNEES
# 10  https://fr.indeed.com/viewjob?jk=b1e6e8a5b68b296b  GESTIONNAIRE DONNEES
# 11  https://fr.indeed.com/viewjob?jk=693d73a58599ab1c         DATA ANALYSTE
# 12  https://fr.indeed.com/viewjob?jk=b48099092ca1d8e2          DATA MANAGER
# 13  https://fr.indeed.com/viewjob?jk=dd0b0d1ead377d0c          DATA MANAGER
# 14  https://fr.indeed.com/viewjob?jk=de372ba90e161d50         DATA ANALYSTE
# 15  https://fr.indeed.com/viewjob?jk=9d8890177b894fdc          DATA MANAGER
# 16  https://fr.indeed.com/viewjob?jk=04eb44777b8841c6        DATA ARCHITECT
# 17  https://fr.indeed.com/viewjob?jk=4e167cfbd43a1764            TECHNICIEN
# 18  https://fr.indeed.com/viewjob?jk=6aa665d9f0061296          DATA MANAGER
# 19  https://fr.indeed.com/viewjob?jk=a2fa5cd502a472a2        DATA INGENIEUR
#
#    Typedecontrat                                         Entreprise  \
# 0            CDI                                              INRAE
# 1            CDI  INRAE - Institut National de Recherche pour l'...
# 2            CDD                                INTERACTION ORLEANS
# 3            CDI                                       PB SOLUTIONS
# 4        Intérim                                             Adecco
# 5            CDI                                   ALBA Recrutement
# 6            CDI                                        Hays France
# 7            CDI                                                gfi
# 8            CDD                                     Walters People
# 9            CDI                                  GEORGES MONIN SAS
# 10           CDD                                               CNRS
# 11           CDI                                              Bayer
# 12           CDI                                      EURAXI PHARMA
# 13           CDI                       GIP ALFA CENTRE-VAL DE LOIRE
# 14           CDI                                               ACII
# 15           CDI                                      EURAXI PHARMA
# 16           CDI                                                gfi
# 17           CDI                                          Worldline
# 18           CDI                                                gfi
# 19           CDI                             Chasseresse de talents
#
#     Departement               Region  \
# 0            37  Centre-Val-de-Loire
# 1            37  Centre-Val-de-Loire
# 2            41  Centre-Val-de-Loire
# 3            45  Centre-Val-de-Loire
# 4            37  Centre-Val-de-Loire
# 5            41  Centre-Val-de-Loire
# 6            37  Centre-Val-de-Loire
# 7            37  Centre-Val-de-Loire
# 8            28  Centre-Val-de-Loire
# 9            18  Centre-Val-de-Loire
# 10           37  Centre-Val-de-Loire
# 11           45  Centre-Val-de-Loire
# 12            0  Centre-Val-de-Loire
# 13            0  Centre-Val-de-Loire
# 14           37  Centre-Val-de-Loire
# 15           37  Centre-Val-de-Loire
# 16           45  Centre-Val-de-Loire
# 17           41  Centre-Val-de-Loire
# 18           45  Centre-Val-de-Loire
# 19            0  Centre-Val-de-Loire
#
#                                           Description  Salaire
# 0   Présentation d'INRAE\r\nL’Institut national de...      NaN
# 1   Acteur majeur de la recherche publique, INRAE ...      NaN
# 2   Votre mission :\r\n\r\nL'agence INTERACTION OR...      NaN
# 3   Master Data Specialist / Spécialiste Base Arti...      NaN
# 4   Votre mission\r\n Adecco Tours Tertiaire reche...      NaN
# 5   ALBA Recrutement recherche pour son client, Gr...      NaN
# 6   Intégré au sein de la BU Connectivité, dans un...      NaN
# 7   Mission\r\nEn tant que Data Engineer, vos prin...      NaN
# 8   Nous recrutons un(e) Data Manager H/F pour un ...  34500.0
# 9   Référent de données référentiel F/H\r\nRef. Ap...      NaN
# 10  Date Limite Candidature : jeudi 10 mars 2022\r...  26010.0
# 11  Chez Bayer nous sommes des visionnaires motivé...      NaN
# 12  RESPONSABLE DATA MANAGEMENT F/H\r\nRef. Apec :...      NaN
# 13  Gestionnaire-Développeur Base de données F/H\r...      NaN
# 14  Chez nous on dit ce que l'on fait et on fait c...  40000.0
# 15  EURAXI PHARMA, CRO full services, spécialisée ...  55000.0
# 16  Mission\r\nEt si vous rejoignez une équipe exp...      NaN
# 17  Au sein de la direction des opérations techniq...      NaN
# 18  Mission\r\nLe Directeur de Projet orienté DATA...      NaN
# 19  Je recherche un Data Engineer(CDI), pour le co...  72500.0

# %%
# import des librairies
import sqlite3
#import mysql.connector
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import yaml
# librairie pour lire les slah windows
from pathlib import PurePath

obj = PurePath ('D:\Documents\DevIA\Python\SSH\connect.yml')

with open (obj, 'r') as f:
    conf = yaml.safe_load(f)
my = conf['MYSQL']
conf['MYSQL']['user']
string = f"mysql+pymysql://{my['user']}:{my['password']}@{my['host']}:{my['port']}/bdd_dubiez"
engine = create_engine(string, echo=False)
print(engine)
# Out:
# Engine(mysql+pymysql://blanchet-durand:***@127.0.0.1:3306/bdd_dubiez)

# %%
df = pd.read_csv('France_V11.csv')
df.head()
df.to_sql(name='Indeed_Salaries',con=string, if_exists='replace', index=False)

# %%
df = pd.read_csv('df_final_V2.csv')
df.dropna(subset = ["Salaire"], inplace=True)
df.to_sql(name='Indeed_Salaries_Finale',con=string, if_exists='replace', index=False)

# %%
df.to_csv('df_final_V2.csv', index = False)

# %% [markdown]
# # Nettoyage Bis

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('df_final_V2.csv')

# %%
df.Departement.replace(0 , 'Télétravail', inplace = True)
df.Departement.value_counts()
# Out:
# Télétravail    68
# 75             27
# 33             25
# 59             23
# 92             18
# 13             18
# 69             15
# 31             14
# 44             10
# 37              8
# 6               7
# 76              7
# 57              6
# 34              5
# 29              5
# 49              5
# 25              4
# 74              4
# 93              3
# 94              3
# 35              3
# 17              3
# 62              3
# 47              3
# 14              3
# 90              2
# 19              2
# 87              2
# 71              2
# 66              2
# 51              2
# 12              2
# 64              2
# 28              2
# 27              2
# 32              2
# 1               2
# 91              1
# 78              1
# 50              1
# 42              1
# 63              1
# 60              1
# 80              1
# 18              1
# 77              1
# 21              1
# 41              1
# 68              1
# 85              1
# 11              1
# 53              1
# 45              1
# Name: Departement, dtype: int64

# %%
df.Poste.replace('0', 'AUTRES', inplace = True)
df.Poste.value_counts()
# Out:
# DATA MANAGER            87
# DATA ANALYSTE           46
# AUTRES                  42
# DATA SCIENTIST          41
# DATA INGENIEUR          41
# GESTIONNAIRE DONNEES    36
# DATA ARCHITECT          12
# TECHNICIEN              10
# CONSULTANT              10
# DEVELOPPEUR              3
# DATA MARKETING           2
# Name: Poste, dtype: int64

# %%
df.Typedecontrat.value_counts()
# Out:
# CDI        263
# CDD         43
# Intérim     24
# Name: Typedecontrat, dtype: int64

# %%
df.Region.value_counts()
# Out:
# Île-de-France                 69
# Nouvelle-Aquitaine            44
# Provence-Âlpes-Côte-D'Azur    36
# Hauts-De-France               33
# Auvergne-Rhône-Alpes          32
# Occitanie                     32
# Pays de la Loire              19
# Normandie                     17
# Centre-Val-de-Loire           15
# Grand-Est                     12
# Bourgogne-Franche-Comté       11
# Bretagne                      10
# Name: Region, dtype: int64

# %%
df.Departement.replace('78', 'Autres', inplace = True)
df.Departement.replace('50', 'Autres', inplace = True)
df.Departement.replace('42', 'Autres', inplace = True)
df.Departement.replace('63', 'Autres', inplace = True)
df.Departement.replace('60', 'Autres', inplace = True)
df.Departement.replace('80', 'Autres', inplace = True)
df.Departement.replace('18', 'Autres', inplace = True)
df.Departement.replace('77', 'Autres', inplace = True)
df.Departement.replace('21', 'Autres', inplace = True)
df.Departement.replace('41', 'Autres', inplace = True)
df.Departement.replace('68', 'Autres', inplace = True)
df.Departement.replace('85', 'Autres', inplace = True)
df.Departement.replace('11', 'Autres', inplace = True)
df.Departement.replace('53', 'Autres', inplace = True)
df.Departement.replace('45', 'Autres', inplace = True)
df.Departement.value_counts()
df.to_csv('df_final_V3.csv', index = False)

# %%
df.Departement.value_counts()
# Out:
# Télétravail    68
# 75             27
# 33             25
# 59             23
# 92             18
# 13             18
# Autres         16
# 69             15
# 31             14
# 44             10
# 37              8
# 76              7
# 6               7
# 57              6
# 29              5
# 34              5
# 49              5
# 25              4
# 74              4
# 14              3
# 17              3
# 35              3
# 62              3
# 93              3
# 94              3
# 47              3
# 19              2
# 87              2
# 71              2
# 66              2
# 90              2
# 51              2
# 1               2
# 32              2
# 12              2
# 28              2
# 64              2
# 27              2
# Name: Departement, dtype: int64

# %%
df.to_csv('df_final_V2.csv', index = False)

# %% [markdown]
# # PyCaret

# %%
# check version
from pycaret.utils import version
version()
# Out:
# '2.3.6'

# %%
import pandas as pd
df = pd.read_csv("df_final_V3.csv")
df.drop(['Lien', 'Entreprise', 'Description', 'Region'], axis = 1, inplace = True)
print(df.dtypes)
df.head()
# Out:
# Poste             object
# Typedecontrat     object
# Departement       object
# Salaire          float64
# dtype: object
#             Poste Typedecontrat  Departement  Salaire
# 0      TECHNICIEN           CDI           71  35500.0
# 1      TECHNICIEN           CDD           71  37500.0
# 2    DATA MANAGER           CDI            1  25000.0
# 3          AUTRES           CDI            1  50000.0
# 4  DATA SCIENTIST           CDD  Télétravail  25200.0

# %%
from pycaret.regression import *
clf1 = setup(data = df, target = "Salaire",
             session_id = 42,
             categorical_features = ['Poste', 'Typedecontrat', 'Departement'])
# Out:
# <style type="text/css">
# #T_3add7_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3add7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3add7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3add7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3add7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3add7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3add7_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3add7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3add7_row1_col1" class="data row1 col1" >Salaire</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3add7_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_3add7_row2_col1" class="data row2 col1" >(330, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3add7_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_3add7_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3add7_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_3add7_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3add7_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_3add7_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3add7_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_3add7_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3add7_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_3add7_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3add7_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_3add7_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3add7_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_3add7_row9_col1" class="data row9 col1" >(230, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3add7_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_3add7_row10_col1" class="data row10 col1" >(100, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3add7_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_3add7_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3add7_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_3add7_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3add7_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_3add7_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3add7_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_3add7_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3add7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_3add7_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3add7_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_3add7_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3add7_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_3add7_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3add7_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_3add7_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3add7_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_3add7_row19_col1" class="data row19 col1" >1c78</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3add7_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_3add7_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3add7_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_3add7_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3add7_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_3add7_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3add7_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_3add7_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3add7_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_3add7_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3add7_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_3add7_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3add7_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_3add7_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3add7_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_3add7_row27_col1" class="data row27 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_3add7_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_3add7_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_3add7_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_3add7_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3add7_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_3add7_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_3add7_row30_col1" class="data row30 col1" >None</td>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_27579 th {
#   text-align: left;
# }
# #T_27579_row0_col0, #T_27579_row0_col6, #T_27579_row1_col0, #T_27579_row1_col1, #T_27579_row1_col2, #T_27579_row1_col3, #T_27579_row1_col4, #T_27579_row1_col5, #T_27579_row1_col6, #T_27579_row2_col0, #T_27579_row2_col1, #T_27579_row2_col2, #T_27579_row2_col3, #T_27579_row2_col4, #T_27579_row2_col5, #T_27579_row2_col6, #T_27579_row3_col0, #T_27579_row3_col1, #T_27579_row3_col2, #T_27579_row3_col3, #T_27579_row3_col4, #T_27579_row3_col5, #T_27579_row3_col6, #T_27579_row4_col0, #T_27579_row4_col1, #T_27579_row4_col2, #T_27579_row4_col3, #T_27579_row4_col4, #T_27579_row4_col5, #T_27579_row4_col6, #T_27579_row5_col0, #T_27579_row5_col1, #T_27579_row5_col2, #T_27579_row5_col3, #T_27579_row5_col4, #T_27579_row5_col5, #T_27579_row6_col0, #T_27579_row6_col1, #T_27579_row6_col2, #T_27579_row6_col3, #T_27579_row6_col4, #T_27579_row6_col5, #T_27579_row6_col6, #T_27579_row7_col0, #T_27579_row7_col1, #T_27579_row7_col2, #T_27579_row7_col3, #T_27579_row7_col4, #T_27579_row7_col5, #T_27579_row7_col6, #T_27579_row8_col0, #T_27579_row8_col1, #T_27579_row8_col2, #T_27579_row8_col3, #T_27579_row8_col4, #T_27579_row8_col5, #T_27579_row8_col6, #T_27579_row9_col0, #T_27579_row9_col1, #T_27579_row9_col2, #T_27579_row9_col3, #T_27579_row9_col4, #T_27579_row9_col5, #T_27579_row9_col6, #T_27579_row10_col0, #T_27579_row10_col1, #T_27579_row10_col2, #T_27579_row10_col3, #T_27579_row10_col4, #T_27579_row10_col5, #T_27579_row10_col6, #T_27579_row11_col0, #T_27579_row11_col1, #T_27579_row11_col2, #T_27579_row11_col3, #T_27579_row11_col4, #T_27579_row11_col5, #T_27579_row11_col6, #T_27579_row12_col0, #T_27579_row12_col1, #T_27579_row12_col2, #T_27579_row12_col3, #T_27579_row12_col4, #T_27579_row12_col5, #T_27579_row12_col6, #T_27579_row13_col0, #T_27579_row13_col1, #T_27579_row13_col2, #T_27579_row13_col3, #T_27579_row13_col4, #T_27579_row13_col5, #T_27579_row13_col6, #T_27579_row14_col0, #T_27579_row14_col1, #T_27579_row14_col2, #T_27579_row14_col3, #T_27579_row14_col4, #T_27579_row14_col5, #T_27579_row14_col6, #T_27579_row15_col0, #T_27579_row15_col1, #T_27579_row15_col2, #T_27579_row15_col3, #T_27579_row15_col4, #T_27579_row15_col5, #T_27579_row15_col6, #T_27579_row16_col0, #T_27579_row16_col1, #T_27579_row16_col2, #T_27579_row16_col3, #T_27579_row16_col4, #T_27579_row16_col5, #T_27579_row16_col6, #T_27579_row17_col0, #T_27579_row17_col1, #T_27579_row17_col2, #T_27579_row17_col3, #T_27579_row17_col4, #T_27579_row17_col5, #T_27579_row17_col6, #T_27579_row18_col0, #T_27579_row18_col1, #T_27579_row18_col2, #T_27579_row18_col3, #T_27579_row18_col4, #T_27579_row18_col5, #T_27579_row18_col6, #T_27579_row19_col0, #T_27579_row19_col1, #T_27579_row19_col2, #T_27579_row19_col3, #T_27579_row19_col4, #T_27579_row19_col5, #T_27579_row19_col6 {
#   text-align: left;
# }
# #T_27579_row0_col1, #T_27579_row0_col2, #T_27579_row0_col3, #T_27579_row0_col4, #T_27579_row0_col5, #T_27579_row5_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_27579_row0_col7, #T_27579_row1_col7, #T_27579_row2_col7, #T_27579_row3_col7, #T_27579_row4_col7, #T_27579_row5_col7, #T_27579_row6_col7, #T_27579_row7_col7, #T_27579_row9_col7, #T_27579_row10_col7, #T_27579_row13_col7, #T_27579_row14_col7, #T_27579_row15_col7, #T_27579_row16_col7, #T_27579_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_27579_row8_col7, #T_27579_row11_col7, #T_27579_row12_col7, #T_27579_row17_col7, #T_27579_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_27579">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27579_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_27579_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_27579_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_27579_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_27579_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_27579_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_27579_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_27579_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27579_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_27579_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_27579_row0_col1" class="data row0 col1" >7861.8225</td>
#       <td id="T_27579_row0_col2" class="data row0 col2" >127061533.5246</td>
#       <td id="T_27579_row0_col3" class="data row0 col3" >10794.4268</td>
#       <td id="T_27579_row0_col4" class="data row0 col4" >0.3284</td>
#       <td id="T_27579_row0_col5" class="data row0 col5" >0.2678</td>
#       <td id="T_27579_row0_col6" class="data row0 col6" >0.2115</td>
#       <td id="T_27579_row0_col7" class="data row0 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_27579_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_27579_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_27579_row1_col1" class="data row1 col1" >8215.0335</td>
#       <td id="T_27579_row1_col2" class="data row1 col2" >132352228.0456</td>
#       <td id="T_27579_row1_col3" class="data row1 col3" >11092.6224</td>
#       <td id="T_27579_row1_col4" class="data row1 col4" >0.3088</td>
#       <td id="T_27579_row1_col5" class="data row1 col5" >0.2759</td>
#       <td id="T_27579_row1_col6" class="data row1 col6" >0.2247</td>
#       <td id="T_27579_row1_col7" class="data row1 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_27579_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_27579_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_27579_row2_col1" class="data row2 col1" >8543.5020</td>
#       <td id="T_27579_row2_col2" class="data row2 col2" >138134545.3899</td>
#       <td id="T_27579_row2_col3" class="data row2 col3" >11318.7036</td>
#       <td id="T_27579_row2_col4" class="data row2 col4" >0.2773</td>
#       <td id="T_27579_row2_col5" class="data row2 col5" >0.2807</td>
#       <td id="T_27579_row2_col6" class="data row2 col6" >0.2339</td>
#       <td id="T_27579_row2_col7" class="data row2 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_27579_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_27579_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_27579_row3_col1" class="data row3 col1" >8332.3495</td>
#       <td id="T_27579_row3_col2" class="data row3 col2" >138493585.7419</td>
#       <td id="T_27579_row3_col3" class="data row3 col3" >11281.5897</td>
#       <td id="T_27579_row3_col4" class="data row3 col4" >0.2762</td>
#       <td id="T_27579_row3_col5" class="data row3 col5" >0.2851</td>
#       <td id="T_27579_row3_col6" class="data row3 col6" >0.2297</td>
#       <td id="T_27579_row3_col7" class="data row3 col7" >0.1140</td>
#     </tr>
#     <tr>
#       <th id="T_27579_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_27579_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_27579_row4_col1" class="data row4 col1" >8595.9790</td>
#       <td id="T_27579_row4_col2" class="data row4 col2" >139921053.5462</td>
#       <td id="T_27579_row4_col3" class="data row4 col3" >11485.8367</td>
#       <td id="T_27579_row4_col4" class="data row4 col4" >0.2669</td>
#       <td id="T_27579_row4_col5" class="data row4 col5" >0.2790</td>
#       <td id="T_27579_row4_col6" class="data row4 col6" >0.2329</td>
#       <td id="T_27579_row4_col7" class="data row4 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_27579_level0_row5" class="row_heading level0 row5" >par</th>
#       <td id="T_27579_row5_col0" class="data row5 col0" >Passive Aggressive Regressor</td>
#       <td id="T_27579_row5_col1" class="data row5 col1" >8288.2325</td>
#       <td id="T_27579_row5_col2" class="data

# %%
model = create_model('rf')
tuned = tune_model(model, n_iter = 100)
# Out:
# <style type="text/css">
# #T_a641a_row10_col0, #T_a641a_row10_col1, #T_a641a_row10_col2, #T_a641a_row10_col3, #T_a641a_row10_col4, #T_a641a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a641a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a641a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a641a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a641a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a641a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a641a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a641a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a641a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a641a_row0_col0" class="data row0 col0" >10389.9031</td>
#       <td id="T_a641a_row0_col1" class="data row0 col1" >287635026.8658</td>
#       <td id="T_a641a_row0_col2" class="data row0 col2" >16959.8062</td>
#       <td id="T_a641a_row0_col3" class="data row0 col3" >-0.1614</td>
#       <td id="T_a641a_row0_col4" class="data row0 col4" >0.3372</td>
#       <td id="T_a641a_row0_col5" class="data row0 col5" >0.2304</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a641a_row1_col0" class="data row1 col0" >4825.5144</td>
#       <td id="T_a641a_row1_col1" class="data row1 col1" >32417795.7947</td>
#       <td id="T_a641a_row1_col2" class="data row1 col2" >5693.6628</td>
#       <td id="T_a641a_row1_col3" class="data row1 col3" >0.7371</td>
#       <td id="T_a641a_row1_col4" class="data row1 col4" >0.1609</td>
#       <td id="T_a641a_row1_col5" class="data row1 col5" >0.1358</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a641a_row2_col0" class="data row2 col0" >7947.2501</td>
#       <td id="T_a641a_row2_col1" class="data row2 col1" >98087649.7481</td>
#       <td id="T_a641a_row2_col2" class="data row2 col2" >9903.9209</td>
#       <td id="T_a641a_row2_col3" class="data row2 col3" >0.6491</td>
#       <td id="T_a641a_row2_col4" class="data row2 col4" >0.2469</td>
#       <td id="T_a641a_row2_col5" class="data row2 col5" >0.2099</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a641a_row3_col0" class="data row3 col0" >9868.2897</td>
#       <td id="T_a641a_row3_col1" class="data row3 col1" >191074407.9227</td>
#       <td id="T_a641a_row3_col2" class="data row3 col2" >13822.9667</td>
#       <td id="T_a641a_row3_col3" class="data row3 col3" >0.2776</td>
#       <td id="T_a641a_row3_col4" class="data row3 col4" >0.2925</td>
#       <td id="T_a641a_row3_col5" class="data row3 col5" >0.2256</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a641a_row4_col0" class="data row4 col0" >6390.9132</td>
#       <td id="T_a641a_row4_col1" class="data row4 col1" >63024744.0374</td>
#       <td id="T_a641a_row4_col2" class="data row4 col2" >7938.8125</td>
#       <td id="T_a641a_row4_col3" class="data row4 col3" >0.2853</td>
#       <td id="T_a641a_row4_col4" class="data row4 col4" >0.1997</td>
#       <td id="T_a641a_row4_col5" class="data row4 col5" >0.1675</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a641a_row5_col0" class="data row5 col0" >6965.2692</td>
#       <td id="T_a641a_row5_col1" class="data row5 col1" >76205831.9680</td>
#       <td id="T_a641a_row5_col2" class="data row5 col2" >8729.5952</td>
#       <td id="T_a641a_row5_col3" class="data row5 col3" >0.5327</td>
#       <td id="T_a641a_row5_col4" class="data row5 col4" >0.2419</td>
#       <td id="T_a641a_row5_col5" class="data row5 col5" >0.2127</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a641a_row6_col0" class="data row6 col0" >7832.4636</td>
#       <td id="T_a641a_row6_col1" class="data row6 col1" >115458974.7537</td>
#       <td id="T_a641a_row6_col2" class="data row6 col2" >10745.1838</td>
#       <td id="T_a641a_row6_col3" class="data row6 col3" >0.4424</td>
#       <td id="T_a641a_row6_col4" class="data row6 col4" >0.2438</td>
#       <td id="T_a641a_row6_col5" class="data row6 col5" >0.1858</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a641a_row7_col0" class="data row7 col0" >9127.0667</td>
#       <td id="T_a641a_row7_col1" class="data row7 col1" >122750613.5223</td>
#       <td id="T_a641a_row7_col2" class="data row7 col2" >11079.2876</td>
#       <td id="T_a641a_row7_col3" class="data row7 col3" >0.5578</td>
#       <td id="T_a641a_row7_col4" class="data row7 col4" >0.3219</td>
#       <td id="T_a641a_row7_col5" class="data row7 col5" >0.2790</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a641a_row8_col0" class="data row8 col0" >7977.4898</td>
#       <td id="T_a641a_row8_col1" class="data row8 col1" >107388786.4084</td>
#       <td id="T_a641a_row8_col2" class="data row8 col2" >10362.8561</td>
#       <td id="T_a641a_row8_col3" class="data row8 col3" >0.4520</td>
#       <td id="T_a641a_row8_col4" class="data row8 col4" >0.2712</td>
#       <td id="T_a641a_row8_col5" class="data row8 col5" >0.2337</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a641a_row9_col0" class="data row9 col0" >7099.1062</td>
#       <td id="T_a641a_row9_col1" class="data row9 col1" >127966966.0174</td>
#       <td id="T_a641a_row9_col2" class="data row9 col2" >11312.2485</td>
#       <td id="T_a641a_row9_col3" class="data row9 col3" >-0.0443</td>
#       <td id="T_a641a_row9_col4" class="data row9 col4" >0.3601</td>
#       <td id="T_a641a_row9_col5" class="data row9 col5" >0.2790</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a641a_row10_col0" class="data row10 col0" >7842.3266</td>
#       <td id="T_a641a_row10_col1" class="data row10 col1" >122201079.7039</td>
#       <td id="T_a641a_row10_col2" class="data row10 col2" >10654.8340</td>
#       <td id="T_a641a_row10_col3" class="data row10 col3" >0.3728</td>
#       <td id="T_a641a_row10_col4" class="data row10 col4" >0.2676</td>
#       <td id="T_a641a_row10_col5" class="data row10 col5" >0.2159</td>
#     </tr>
#     <tr>
#       <th id="T_a641a_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_a641a_row11_col0" class="data row11 col0" >1574.9276</td>
#       <td id="T_a641a_row11_col1" class="data row11 col1" >68315613.6975</td>
#       <td id="T_a641a_row11_col2" class="data row11 col2" >2945.4357</td>
#       <td id="T_a641a_row11_col3" class="data row11 col3" >0.2750</td>
#       <td id="T_a641a_row11_col4" class="data row11 col4" >0.0588</td>
#       <td id="T_a641a_row11_col5" class="data row11 col5" >0.0428</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features=1.0, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.005,
#                       min_impurity_split=None, min_samples_leaf=5,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=40, n_jobs=-1, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
evaluate_model(tuned)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
plot_model(tuned, plot = 'feature')

# %% [markdown]
# # Preprocessing + ML

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score, mean_absolute_error

# %%
import pandas as pd
df = pd.read_csv("df_final_V2.csv")
df.drop(['Lien', 'Entreprise', 'Description', 'Region'], axis = 1, inplace = True)
print(df.dtypes)
df.head()
# Out:
# Poste             object
# Typedecontrat     object
# Departement       object
# Salaire          float64
# dtype: object
#             Poste Typedecontrat  Departement  Salaire
# 0      TECHNICIEN           CDI           71  35500.0
# 1      TECHNICIEN           CDD           71  37500.0
# 2    DATA MANAGER           CDI            1  25000.0
# 3          AUTRES           CDI            1  50000.0
# 4  DATA SCIENTIST           CDD  Télétravail  25200.0

# %%
y = df.Salaire

# %%
X = df.drop(columns = 'Salaire')
X
# Out:
#               Poste Typedecontrat  Departement
# 0        TECHNICIEN           CDI           71
# 1        TECHNICIEN           CDD           71
# 2      DATA MANAGER           CDI            1
# 3            AUTRES           CDI            1
# 4    DATA SCIENTIST           CDD  Télétravail
# ..              ...           ...          ...
# 325          AUTRES           CDI  Télétravail
# 326  DATA INGENIEUR           CDI  Télétravail
# 327    DATA MANAGER           CDI           27
# 328    DATA MANAGER           CDI           27
# 329  DATA INGENIEUR           CDD           14
#
# [330 rows x 3 columns]

# %%
transformer = Pipeline(steps = [
    ('OneHotEncoder', OneHotEncoder(sparse = False))])

# %%
Prep = ColumnTransformer(transformers = [
    ('cat', transformer, X.columns)])

# %%
model = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=6, max_features=1.0, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.005,
                      min_impurity_split=None, min_samples_leaf=5,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=40, n_jobs=-1, oob_score=False,
                      random_state=42, verbose=0, warm_start=False)

# %%
pipe_model = Pipeline(steps = [
    ('preparation', Prep),
    ('model', model)])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state =3)

# %%
pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preparation',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('OneHotEncoder',
#                                                                    OneHotEncoder(sparse=False))]),
#                                                   Index(['Poste', 'Typedecontrat', 'Departement'], dtype='object'))])),
#                 ('model',
#                  RandomForestRegressor(max_depth=6, max_features=1.0,
#                                        min_impurity_decrease=0.005,
#                                        min_samples_leaf=5, n_estimators=40,
#                                        n_jobs=-1, random_state=42))])

# %%
y_pred = pipe_model.predict(X_test)

# %%
score1 = r2_score(y_test, y_pred)
score2 = mean_absolute_error(y_test, y_pred)
print("R² Score =", score1, "\nMAE =",score2)
# Out:
# R² Score = 0.5109987222281536
# MAE = 8106.658946816786

# %%
X_test
# Out:
#               Poste Typedecontrat  Departement
# 118      TECHNICIEN           CDI       Autres
# 198   DATA ANALYSTE           CDI           75
# 299  DATA INGENIEUR           CDI  Télétravail
# 15   DATA INGENIEUR           CDI           69
# 84     DATA MANAGER       Intérim           59
# ..              ...           ...          ...
# 123  DATA SCIENTIST           CDI           37
# 257    DATA MANAGER       Intérim           49
# 25    DATA ANALYSTE           CDI  Télétravail
# 67       CONSULTANT           CDI           33
# 127   DATA ANALYSTE           CDI       Autres
#
# [83 rows x 3 columns]

# %%
import pickle
pickle.dump(pipe_model, open('finalized_model.sav', 'wb'))

# %%
loaded_model = pickle.load(open('finalized_model.sav', 'rb'))

pred = pd.DataFrame( {'Poste': ['TECHNICIEN'],
             'Typedecontrat': ['CDD'],
             'Departement': ['35']})

loaded_model.predict(pred)
# Out:
# array([31240.24554249])

# %%
# Extract single tree
estimator = model.estimators_[5]

# %%
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
import os

os.environ['PATH'] = os.environ['PATH']+';'+os.environ['CONDA_PREFIX']+r"\Library\bin\graphviz"
dot_data = StringIO()
export_graphviz(pipe_model.named_steps['model'].estimators_[2], out_file=dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue()) 
Image(graph.create_png())
