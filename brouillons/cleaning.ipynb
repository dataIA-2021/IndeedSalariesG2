# %%
import pandas as pd
import re

# %%
df = pd.read_csv('Indeed_Salaries.csv')
df.head()
# Out:
#                                                 Lien  \
# 0  https://fr.indeed.com/viewjob?jk=5b2e4528626a2c37
# 1  https://fr.indeed.com/viewjob?jk=a25ddcc7a0af8396
# 2  https://fr.indeed.com/viewjob?jk=ba5c2f88b0176120
# 3  https://fr.indeed.com/viewjob?jk=d1fa73c363aa27d0
# 4  https://fr.indeed.com/viewjob?jk=6f7788bc07e79181
#
#                                                Poste  \
# 0                                Ingénieur-e données
# 1                                Ingénieur-e données
# 2  TECHNICIEN EN GESTION DE DONNEES TECHNIQUES SA...
# 3  Master Data Specialist / Spécialiste Base Arti...
# 4              Gestionnaire de Base de Données (h/f)
#
#                                           Entreprise            Localisation  \
# 0                                              INRAE          37380 Nouzilly
# 1  INRAE - Institut National de Recherche pour l'...           Nouzilly (37)
# 2                                INTERACTION ORLEANS               41500 Mer
# 3                                       PB SOLUTIONS  Beaune-la-Rolande (45)
# 4                                             Adecco    37300 Joué-lés-Tours
#
#     Type de Contrat Salaire  \
# 0       Temps plein     NaN
# 1  Temps plein, CDI     NaN
# 2  Temps plein, CDD     NaN
# 3               CDI     NaN
# 4           Intérim     NaN
#
#                                          Description  Nombre d'avis  \
# 0  Présentation d'INRAE\nL’Institut national de r...            2.0
# 1  Acteur majeur de la recherche publique, INRAE ...            NaN
# 2  Votre mission :\n\nL'agence INTERACTION ORLEAN...           88.0
# 3  Master Data Specialist / Spécialiste Base Arti...            NaN
# 4  Votre mission\n Adecco Tours Tertiaire recherc...            NaN
#
#    Note Moyenne  Diplôme  Années d'expérience  Type de contrat  \
# 0           4.0      NaN                  NaN              NaN
# 1           NaN      NaN                  NaN              NaN
# 2           3.7      NaN                  NaN              NaN
# 3           NaN      NaN                  NaN              NaN
# 4           NaN      NaN                  NaN              NaN
#
#    Temps de travail  Technologies  Langues  Industrie  Département
# 0               NaN           NaN      NaN        NaN          NaN
# 1               NaN           NaN      NaN        NaN          NaN
# 2               NaN           NaN      NaN        NaN          NaN
# 3               NaN           NaN      NaN        NaN          NaN
# 4               NaN           NaN      NaN        NaN          NaN

# %%
for column in df.columns:
    df['Poste']=df['Poste'].str.replace('H/F', "")
    df['Poste']=df['Poste'].str.replace('h/f', "")
    df['Poste']=df['Poste'].str.replace('("")',"")    
df
# Out:
# /var/folders/xh/992blmm116gfjsjxnphl232w0000gn/T/ipykernel_68821/2237752831.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Poste']=df['Poste'].str.replace('("")',"")
#                                                   Lien  \
# 0    https://fr.indeed.com/viewjob?jk=5b2e4528626a2c37
# 1    https://fr.indeed.com/viewjob?jk=a25ddcc7a0af8396
# 2    https://fr.indeed.com/viewjob?jk=ba5c2f88b0176120
# 3    https://fr.indeed.com/viewjob?jk=d1fa73c363aa27d0
# 4    https://fr.indeed.com/viewjob?jk=6f7788bc07e79181
# ..                                                 ...
# 108  https://fr.indeed.com/viewjob?jk=0c4454f31cf2ebe7
# 109  https://fr.indeed.com/viewjob?jk=9a5cfca2c8b55cac
# 110  https://fr.indeed.com/viewjob?jk=f28e995b8813aded
# 111  https://fr.indeed.com/viewjob?jk=fb8a33c83287bcbf
# 112  https://fr.indeed.com/viewjob?jk=ca85d5315b7a2582
#
#                                                  Poste  \
# 0                                  Ingénieur-e données
# 1                                  Ingénieur-e données
# 2    TECHNICIEN EN GESTION DE DONNEES TECHNIQUES SA...
# 3    Master Data Specialist / Spécialiste Base Arti...
# 4                   Gestionnaire de Base de Données ()
# ..                                                 ...
# 108     Data Analytics Engineer / BI Engineer () - CDI
# 109                                      Data Manager
# 110                Data Scientist Time Series () - CDI
# 111                  Advisory DATA Architect - Kyndryl
# 112                      Data Analyst Manager () - CDI
#
#                                             Entreprise  \
# 0                                                INRAE
# 1    INRAE - Institut National de Recherche pour l'...
# 2                                  INTERACTION ORLEANS
# 3                                         PB SOLUTIONS
# 4                                               Adecco
# ..                                                 ...
# 108                                         Jellysmack
# 109                                     Walters People
# 110                                         Jellysmack
# 111                                            Kyndryl
# 112                                         Jellysmack
#
#                Localisation   Type de Contrat                     Salaire  \
# 0            37380 Nouzilly       Temps plein                         NaN
# 1             Nouzilly (37)  Temps plein, CDI                         NaN
# 2                 41500 Mer  Temps plein, CDD                         NaN
# 3    Beaune-la-Rolande (45)               CDI                         NaN
# 4      37300 Joué-lés-Tours           Intérim                         NaN
# ..                      ...               ...                         ...
# 108                  France       Temps plein                         NaN
# 109           Chartres (28)            -  CDD  32 000 € - 37 000 € par an
# 110                  France       Temps plein                         NaN
# 111                  France       Temps plein                         NaN
# 112                  France       Temps plein                         NaN
#
#                                            Description  Nombre d'avis  \
# 0    Présentation d'INRAE\nL’Institut national de r...            2.0
# 1    Acteur majeur de la recherche publique, INRAE ...            NaN
# 2    Votre mission :\n\nL'agence INTERACTION ORLEAN...           88.0
# 3    Master Data Specialist / Spécialiste Base Arti...            NaN
# 4    Votre mission\n Adecco Tours Tertiaire recherc...            NaN
# ..                                                 ...            ...
# 108  Jellysmack is the global creator company that ...           24.0
# 109  Nous recrutons un(e) Data Manager H/F pour un ...           42.0
# 110  Jellysmack is the global creator company that ...           24.0
# 111  492306BR\nWhy Kyndryl\nOur world has never bee...            NaN
# 112  Jellysmack is the global creator company that ...           24.0
#
#      Note Moyenne  Diplôme  Années d'expérience  Type de contrat  \
# 0             4.0      NaN                  NaN              NaN
# 1             NaN      NaN                  NaN              NaN
# 2             3.7      NaN                  NaN              NaN
# 3             NaN      NaN                  NaN              NaN
# 4             NaN      NaN                  NaN              NaN
# ..            ...      ...                  ...              ...
# 108           4.2      NaN                  NaN              NaN
# 109           3.1      NaN                  NaN              NaN
# 110           4.2      NaN                  NaN              NaN
# 111           NaN      NaN                  NaN              NaN
# 112           4.2      NaN                  NaN              NaN
#
#      Temps de travail  Technologies  Langues  Industrie  Département  salaire
# 0                 NaN           NaN      NaN        NaN          NaN        0
# 1                 NaN           NaN      NaN        NaN          NaN        0
# 2                 NaN           NaN      NaN        NaN          NaN        0
# 3                 NaN           NaN      NaN        NaN          NaN        0
# 4                 NaN           NaN      NaN        NaN          NaN        0
# ..                ...           ...      ...        ...          ...      ...
# 108               NaN           NaN      NaN        NaN          NaN        0
# 109               NaN           NaN      NaN        NaN          NaN        0
# 110               NaN           NaN      NaN        NaN          NaN        0
# 111               NaN           NaN      NaN        NaN          NaN        0
# 112               NaN           NaN      NaN        NaN          NaN        0
#
# [113 rows x 18 columns]
